# %% [markdown]
# #### matplotlib.pyplot is a collection of command style functions that make matplotlib work like MATLA

# %% [raw]
# If you provide a single list or array to the plot() command, matplotlib assumes it is a sequence of y values, and automatically generates the x values for you.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
# Out:
# Text(0,0.5,'some numbers')

# %%
# plot()是一个通用命令，可以接受任意数量的参数
plt.plot([1,2,3,4],[1,4,9,16])

# %% [raw]
# For every x, y pair of arguments, there is an optional third argument which is the format string that indicates the color and line type of the plot,The letters and symbols of the format string are from MATLAB, and you concatenate a color string with a line style string. The default format string is 'b-', which is a solid blue line

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
# axis(xmin, xmax, ymin, ymax)
plt.axis([0,6,0,20])
# Out:
# [0, 6, 0, 20]

# %%
# you will use numpy arrays in plt
import numpy as np
t = np.arange(0,5,0.2)
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
# Out:
# [<matplotlib.lines.Line2D at 0x22f9fe6c9e8>,
#  <matplotlib.lines.Line2D at 0x22f9fe6cc18>,
#  <matplotlib.lines.Line2D at 0x22f9fe750f0>]

# %% [markdown]
# #### Plotting with keyword strings

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0,50,50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

# %%
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
# Out:
# Text(0,0.5,'entry b')

# %% [markdown]
# #### Plotting with categorical variables

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(1,figsize=(9,3))
plt.subplot(132)
plt.bar(names, values)

plt.subplot(131)
plt.scatter(names, values)

plt.subplot(133)
plt.plot(names,values)

plt.suptitle('Categorical Plotting')
# Out:
# Text(0.5,0.98,'Categorical Plotting')

# %% [markdown]
# #### Controlling line properties

# %%
lines = plt.plot([1,2,3])

# %% [markdown]
# #### Working with multiple figures and axes

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)
t1 = np.arange(0,5,0.1)
t2 = np.arange(0,5,0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1,f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')

# %% [markdown]
# #### Logarithmic and other nonlinear axes

# %%
from matplotlib.ticker import NullFormatter
np.random.seed(19680801)

y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

plt.figure(1)
# linear
plt.subplot(221)
plt.plot(x,y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(222)
plt.plot(x,y)
plt.yscale('log')
plt.title('log')
plt.grid(True)
