# %%
from ggplot import *
print(meat)
# Out:
#           date    beef   veal    pork  lamb_and_mutton  broilers  \
# 0   1944-01-01   751.0   85.0  1280.0             89.0       NaN
# 1   1944-02-01   713.0   77.0  1169.0             72.0       NaN
# 2   1944-03-01   741.0   90.0  1128.0             75.0       NaN
# 3   1944-04-01   650.0   89.0   978.0             66.0       NaN
# 4   1944-05-01   681.0  106.0  1029.0             78.0       NaN
# 5   1944-06-01   658.0  125.0   962.0             79.0       NaN
# 6   1944-07-01   662.0  142.0   796.0             82.0       NaN
# 7   1944-08-01   787.0  175.0   748.0             87.0       NaN
# 8   1944-09-01   774.0  182.0   678.0             91.0       NaN
# 9   1944-10-01   834.0  215.0   777.0            100.0       NaN
# 10  1944-11-01   786.0  197.0   944.0             91.0       NaN
# 11  1944-12-01   764.0  146.0  1013.0             91.0       NaN
# 12  1945-01-01   820.0  119.0  1037.0            100.0       NaN
# ...

# %%
from ggplot import *

p=ggplot(aes(x='date', y='beef'),data=meat)+geom_line()
print(p)
# Out:
# <ggplot: (-9223371844375040915)>

# %%
g=ggplot(diamonds, aes(x='carat', y='price', color='cut')) +geom_point() +scale_color_brewer(type='diverging', palette=4) +xlab("Carats") + ylab("Price") + ggtitle("Diamonds")
print(g)
# Out:
# <ggplot: (192479773283)>

# %%
print(diamonds)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8       0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9       0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10      0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# ...

# %%
s=ggplot(aes(x='carat', y='price', color='clarity'), data=diamonds) + geom_point()+scale_color_brewer(type="seq",palette='OrRd')
print(s)
# Out:
# <ggplot: (192479881999)>

# %%
from ggplot import *
print(mpg.head())
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
p=ggplot(aes(x='displ',y='hwy',data=mpg)+geom_point()
print(p)
# Out:
#   File "<ipython-input-11-5ee7fc37ad33>", line 2
#     print(p)
#         ^
# SyntaxError: invalid syntax

# %%
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)',shape='factor(displ)'),data=mpg)+geom_point()  #注意分类变量要写成'factor(cyl)'而不是factor('cyl)
print(s)
# Out:
# <ggplot: (-9223371903424297521)>

# %%
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)',size='cty'),data=mpg)+geom_point(size=100,alpha=0.5)  #注意分类变量要写成'factor(cyl)'而不是factor('cyl)
print(s)
# Out:
# <ggplot: (133430169790)>

# %%
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point()  #注意分类变量要写成'factor(cyl)'而不是factor('cyl)
print(s)
# Out:
# <ggplot: (133430855579)>

# %%
p=ggplot(aes(x='carat'),data=diamonds)+geom_bar()
print(p)
# Out:
# <ggplot: (133431425614)>

# %%
p=ggplot(aes(x='carat'),data=diamonds)+geom_histogram(fill='steelblue',alpha=0.3)
print(p)
# Out:
# <ggplot: (133430456815)>

# %%
p=ggplot(aes(x='carat'),data=diamonds)+geom_density()
print(p)
# Out:
# <ggplot: (133431123930)>

# %%
s=ggplot(mpg)   #不要搞这么多拆分操作，就正常的就好了
x=s+aes(x='displ',y='hwy',color='factor(cyl)')+geom_point() 
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-fe43d80512f8> in <module>()
# ----> 1 s=ggplot(mpg)   #不要搞这么多拆分操作，就正常的就好了
#       2 x=s+aes(x='displ',y='hwy',color='factor(cyl)')+geom_point()
#       3 print(x)
#
# TypeError: __init__() missing 1 required positional argument: 'data'

# %%
p=ggplot(aes(x='carat'),data=diamonds)
x=p+geom_histogram(fill='steelblue',alpha=0.3)
print(x)
# Out:
# <ggplot: (-9223371903423960853)>

# %%
from ggplot import *
p=ggplot(diamonds,aes('carat'))+geom_histogram(binwidth=0.1)
print(p)
# Out:
# <ggplot: (-9223371903423794295)>

# %%
p=ggplot(diamonds,aes('carat'))+geom_histogram(aes(y='..density..'),binwidth=0.1)
print(p)
# Out:
# <ggplot: (-9223371903423629175)>

# %%
p=ggplot(diamonds,aes(x='carat',y='x'))+geom_bar(binwidth=0.1)
print(p)
# Out:
# <ggplot: (-9223371903423598455)>

# %%
print(diamonds.head())
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
d=ggplot(diamonds,aes('carat'))+xlim(0,3)\
+stat_bin2d(aes(ymax='..count..'),binwidth=0.1,geom='area')
print(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-8e207a620f49> in <module>()
# ----> 1 d=ggplot(diamonds,aes('carat'))+xlim(0,3)+stat_bin2d(aes(ymax='..count..'),binwidth=0.1,geom='area')
#       2 print(d)
#
# NameError: name 'stat_bin2d' is not defined

# %%
from ggplot import *
p=ggplot(mpg,aes(x='cty',y='model'))+facet_grid(manufacture~.,scales='free',space='free')
print(p)
# Out:
#   File "<ipython-input-5-c27456466fb0>", line 2
#     p=ggplot(mpg,aes(x='cty',y='model'))+facet_grid(manufacture~.,scales='free',space='free')
#                                                                ^
# SyntaxError: invalid syntax

# %%
from ggplot import *
print(mpg.head())
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
p=ggplot(mpg,aes(x='cty',y='model',color='(cyl)'))+geom_point()+facet_grid(~manufacturer)
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-490d94271bae> in <module>()
# ----> 1 p=ggplot(mpg,aes(x='cty',y='model',color='(cyl)'))+geom_point()+facet_grid(~manufacturer)
#       2 print(p)
#
# NameError: name 'manufacturer' is not defined

# %%
p=ggplot(data=diamonds, aes(x=carat, y=price))+geom_point() + facet_wrap(~cut)
print(p)
# Out:
#   File "<ipython-input-16-940f683ce90b>", line 1
#     p=ggplot(data=diamonds, aes(x=carat, y=price))+geom_point() + facet_wrap(~cut)
#                            ^
# SyntaxError: positional argument follows keyword argument

# %%
print (ggplot(meat, aes('date','beef'))+\
       geom_line(color='black')+\
       scale_x_date(breaks=date_breaks(), labels='%b %Y')+\
       scale_y_continuous(labels='comma'))+stat_smooth()
# Out:
# <ggplot: (120409355924)>

# %%
print(meat.head())
# Out:
#         date   beef   veal    pork  lamb_and_mutton  broilers  other_chicken  \
# 0 1944-01-01  751.0   85.0  1280.0             89.0       NaN            NaN
# 1 1944-02-01  713.0   77.0  1169.0             72.0       NaN            NaN
# 2 1944-03-01  741.0   90.0  1128.0             75.0       NaN            NaN
# 3 1944-04-01  650.0   89.0   978.0             66.0       NaN            NaN
# 4 1944-05-01  681.0  106.0  1029.0             78.0       NaN            NaN
#
#    turkey
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(stat = 'sum')  #注意分类变量要写成'factor(cyl)'而不是factor('cyl)
print(s)
# Out:
# <ggplot: (110382080397)>

# %%
p=ggplot(aes(x='displ',y='hwy'),data=mpg)+geom_point()+theme_xkcd()
print(p)
# Out:
# <ggplot: (110382160809)>

# %%
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(stat = 'sum')+theme_gray()
print(s)
# Out:
# <ggplot: (110381671716)>

# %%
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(stat = 'sum')+theme_bw()
print(s)
# Out:
# <ggplot: (110381245455)>

# %%
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(stat = 'sum')+theme_xkcd()
print(s)
# Out:
# <ggplot: (110381905875)>

# %%
print(dir(ggplot))
# Out:
# ['CONTINUOUS', 'DISCRETE', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slotnames__', '__str__', '__subclasshook__', '__weakref__', '_construct_plot_data', '_get_mapping', '_handle_index', '_iterate_subplots', '_prep_layer_for_plotting', 'add_labels', 'add_legend', 'apply_axis_labels', 'apply_axis_scales', 'apply_coords', 'apply_limits', 'apply_scales', 'apply_theme', 'get_facet_groups', 'get_subplot', 'make', 'make_facets', 'save', 'save_as_base64', 'show']

# %%
help(ggplot.apply_coords)
# Out:
# Help on function apply_coords in module ggplot.ggplot:
#
# apply_coords(self)

# %%
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(stat = 'sum')+facet_grid(x='cyl',scales='free') #分面这样就完成了
print(s) #fixed | free_x | free_y | free
# Out:
# <ggplot: (-9223371926472626260)>

# %%
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(stat = 'sum')+facet_grid(x='cyl',margins=True) #分面这样就完成了
print(s) #说明做不了边际图
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-0c55089a7aba> in <module>()
# ----> 1 s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(stat = 'sum')+facet_grid(x='cyl',margins=True) #分面这样就完成了
#       2 print(s)
#
# TypeError: __init__() got an unexpected keyword argument 'margins'

# %%
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+xlim(1,10)+ylab('hello')+geom_point(stat = 'sum')+theme_xkcd()#限制x轴的跨度
#命名轴名字的时候不要用中文，格式不太支持，用双引号和单引号都可以
print(s)
# Out:
# <ggplot: (110380994799)>

# %%
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(stat = 'sum')+theme_xkcd()+xlim(1,10) 
#图层还是有上下区别的，设置坐标轴需要靠前一点，如果比较靠后可能会报错
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-0b3c080da44b> in <module>()
# ----> 1 s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(stat = 'sum')+theme_xkcd()+xlim(1,10)
#       2 print(s)
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\chart_components.py in __radd__(self, gg)
#      63
#      64     def __radd__(self, gg):
# ---> 65         gg = deepcopy(gg)
#      66         gg.xlimits = [self.low, self.high]
#      67         return gg
#
# D:\data_analysis_app\pycharm\anaconda\lib\copy.py in deepcopy(x, memo, _nil)
#     178                     y = x
#     179                 else:
# --> 180                     y = _reconstruct(x, memo, *rv)
#     181
#     182     # If is its own copy, don't memoize.
#
# ...

# %%
p=ggplot(mpg,aes(x='class', y='hwy', fill='class'))+geom_violin(alpha=0.5, width=0.9)
print(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-bc55444052b6> in <module>()
#       1 p=ggplot(mpg,aes(x='class', y='hwy', fill='class'))+geom_violin(alpha=0.5, width=0.9)
# ----> 2 print(p)
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in __repr__(self)
#     114
#     115     def __repr__(self):
# --> 116         self.make()
#     117         # this is nice for dev but not the best for "real"
#     118         if os.environ.get("GGPLOT_DEV"):
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in make(self)
#     634                         if kwargs==False:
#     635                             continue
# --> 636                         layer.plot(ax, facetgroup, self._aes, **kwargs)
#     637
#     638             self.apply_limits()
#
# ...

# %%
print(mpg.head())
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
p=ggplot(mpg,aes(x='class',y='hwy',color='cyl'))+geom_violin(aes(fill = 'factor(cyl)'),alpha=0.5, width=0.9)
print(p)
# Out:
# <ggplot: (110382275213)>

# %%
s=ggplot(mtcars, aes(x='factor(cyl)',y= 'mpg')) +geom_violin(aes(fill = 'factor(cyl)')) ##目前fill上不了色
print(s)
# Out:
# <ggplot: (110382631344)>

# %%
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(stat = 'sum')+theme_gray()
#theme_gray :默认主题
# theme_bw:白色主题

print(s)
# Out:
# <ggplot: (-9223371926473531830)>

# %%
p=ggplot(mpg,aes(x='class',y='hwy',color='cyl'))+geom_violin(aes(fill = 'factor(cyl)'),alpha=0.5, width=0.9)
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(stat = 'sum')+theme_gray()
print(p)
print(s)
#print(p,s)
##一页多图
# Out:
# <ggplot: (-9223371926472429729)>
# <ggplot: (110381583382)>

# %%
print(ggplot(mtcars, aes('wt', 'mpg')) + \
    geom_point() +\
    ggtitle("Not Art"))
# Out:
# <ggplot: (-9223371926473775265)>

# %%
print(ggplot(mtcars ，aes (x='wt',y='mpg' ))+ geom_now_its_art()+ggtitle ("Art！"))
# Out:
#   File "<ipython-input-124-e7655fa19afa>", line 1
#     print(ggplot(mtcars ，aes (x='wt',y='mpg' ))+ geom_now_its_art()+ggtitle ("Art！"))
#                            ^
# SyntaxError: invalid character in identifier

# %%
from ggplot import *
p=ggplot(aes(x='carat'),data=diamonds)+geom_histogram(fill='steelblue',alpha=0.5)+coord_polar() #极坐标系--风玫瑰图
print(p)
# Out:
# <ggplot: (139797820708)>

# %%
p=ggplot(mpg,aes(x='class',y='hwy',color='cyl'))+geom_violin(aes(fill = 'factor(cyl)'),alpha=0.5, width=0.9)+theme(axis_text_x=element_text(angle=>90))
print(p)
# Out:
#   File "<ipython-input-8-c0b3445d089d>", line 1
#     p=ggplot(mpg,aes(x='class',y='hwy',color='cyl'))+geom_violin(aes(fill = 'factor(cyl)'),alpha=0.5, width=0.9)+theme(axis_text_x=element_text(angle=>90))
#                                                                                                                                                       ^
# SyntaxError: invalid syntax

# %%
print(budget.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0767dbd150a2> in <module>()
# ----> 1 print(budget.head())
#
# NameError: name 'budget' is not defined

# %%
p=ggplot(aes(x = 'carat', y = 'price', shape = 'cut', colour = 'cut'),data=diamonds)+geom_point(alpha=0.2)+geom_jitter()+facet_grid('cut')
print(p)
# Out:
# <ggplot: (-9223371897046083868)>

# %%
p=ggplot(diamonds,aes(x='cut',y='price',lable='price',color='cut'))+geom_boxplot(size=1.5)+geom_text()
print(p)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-64-194f2e3b92e7> in <module>()
#       1 p=ggplot(diamonds,aes(x='cut',y='price',lable='price',color='cut'))+geom_boxplot(size=1.5)+geom_text()
# ----> 2 print(p)
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in __repr__(self)
#     114
#     115     def __repr__(self):
# --> 116         self.make()
#     117         # this is nice for dev but not the best for "real"
#     118         if os.environ.get("GGPLOT_DEV"):
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in make(self)
#     634                         if kwargs==False:
#     635                             continue
# --> 636                         layer.plot(ax, facetgroup, self._aes, **kwargs)
#     637
#     638             self.apply_limits()
#
# ...

# %%
p=ggplot(diamonds,aes(fill='cut'))+geom_boxplot(aes(x='cut',y='price'))+facet_grid('color',scales="free")
#数据的话在第一层使用，在后面的层叠加的话会报错，这个问题在r里面是不存在的
print(p)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-51742c11c1a9> in <module>()
#       1 p=ggplot(diamonds,aes(fill='cut'))+geom_boxplot(aes(x='cut',y='price'))+facet_grid('color',scales="free")
# ----> 2 print(p)
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in __repr__(self)
#     114
#     115     def __repr__(self):
# --> 116         self.make()
#     117         # this is nice for dev but not the best for "real"
#     118         if os.environ.get("GGPLOT_DEV"):
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in make(self)
#     631                 for ax, facetgroup in self.get_facet_groups(group):
#     632                     for layer in self.layers:
# --> 633                         kwargs = self._prep_layer_for_plotting(layer, facetgroup)
#     634                         if kwargs==False:
# ...

# %%
p=ggplot(mtcars, aes(x='wt', y='mpg',label='name', color='factor(cyl)'))+geom_point() +geom_text() #增加数据标签
print(p)
# Out:
# <ggplot: (-9223371897056974897)>

# %%
print(mtcars.head())
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
print(diamonds.head())
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df=diamonds.sample(frac=0.03)  #使用frac是取比例
df2=diamonds.sample(n=2000) #使用df2就是取行数，这里默认是随机抽行数
#/*
#DataFrame.sample(n=None, frac=None, replace=False, weights=None, random_state=None, axis=None)
#n是要抽取的行数。（例如n=20000时，抽取其中的2W行）
#frac是抽取的比列。（有一些时候，我们并对具体抽取的行数不关系，我们想抽取其中的百分比，这个时候就可以选择使用frac，例如frac=0.8，就是抽取其中80%）
#replace抽样后的数据是否代替原DataFrame()
#weights这个是每个样本的权重，具体可以看官方文档说明。
#random_state这个在之前的文章已经介绍过了。
#axis是选择抽取数据的行还是列。axis=0的时是抽取行，axis=1时是抽取列（也就是说axis=1时，在列中随机抽取n列，在axis=0时，在行中随机抽取n行）
#*/
print(df.describe())
print(df2.describe())
print(diamonds.describe())
# Out:
#              carat        depth        table         price            x  \
# count  1618.000000  1618.000000  1618.000000   1618.000000  1618.000000
# mean      0.795346    61.763041    57.546663   3884.133498     5.716829
# std       0.483919     1.391055     2.162385   3986.893213     1.135016
# min       0.200000    55.900000    52.000000    337.000000     3.840000
# 25%       0.390000    61.100000    56.000000    936.000000     4.670000
# 50%       0.700000    61.800000    57.000000   2346.500000     5.665000
# 75%       1.050000    62.500000    59.000000   5256.500000     6.550000
# max       4.500000    69.800000    70.000000  18674.000000    10.230000
#
#                  y            z
# count  1618.000000  1618.000000
# mean      5.718096     3.532528
# std       1.125578     0.703675
# min       3.800000     2.280000
# 25%       4.690000     2.900000
# 50%       5.680000     3.510000
# 75%       6.547500     4.040000
# max      10.160000     6.720000
# ...

# %%
df=diamonds.sample(frac=0.03)
p=ggplot(aes(x='color',y='price'))

# %%
print(diamonds.head())
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
from ggplot import *
p=ggplot(mtcars, aes(x = 'mpg', y = 'wt'))+geom_point()
print(p)
# Out:
# <ggplot: (-9223371916446117558)>

# %%
from ggplot import *
p=ggplot(mtcars, aes(x = 'mpg', y = 'wt'))+geom_point(aes(color = 'gear'))
###没有图例看到了么
print(p)
# Out:
# <ggplot: (120409147200)>

# %%
from ggplot import *
p=ggplot(mtcars, aes(x = 'mpg', y = 'wt',color = 'gear'))+geom_point()
#注意跟上图的区别
print(p)
# Out:
# <ggplot: (120409178467)>

# %%
from ggplot import *
p=ggplot(mtcars, aes(x = 'mpg', y = 'wt',color = 'gear'))+geom_point(aes(y = 'carb'))
#修改y的映射
print(p)
# Out:
# <ggplot: (-9223371916445590619)>

# %%
from ggplot import *
p=ggplot(mtcars, aes(x = 'mpg', y = 'wt',color = 'gear'))+geom_point(aes(y = 'carb'))+geom_point(aes(color = 'red'))
#用后面的图层颜色遮住前面的图层颜色
print(p)
# Out:
# <ggplot: (-9223371916445597240)>

# %%
from ggplot import *
print(mpg.head())
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
