# %%
import ggplot
dir(ggplot)
# Out:
# ['Facet',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_set_mpl_backend',
#  'absolute_import',
#  'aes',
#  'chart_components',
#  'chopsticks',
#  'colors',
#  'coord_equal',
#  'coord_flip',
#  'coord_polar',
#  'coords',
#  'datasets',
#  'date_breaks',
#  'date_format',
#  'diamonds',
#  'discretemappers',
#  'division',
#  'element_text',
#  'facet_grid',
#  'facet_wrap',
#  'facets',
#  'geom_abline',
#  'geom_area',
#  'geom_bar',
#  'geom_bin2d',
#  'geom_blank',
#  'geom_boxplot',
#  'geom_density',
#  'geom_errorbar',
#  'geom_histogram',
#  'geom_hline',
#  'geom_jitter',
#  'geom_line',
#  'geom_now_its_art',
#  'geom_path',
#  'geom_point',
#  'geom_polygon',
#  'geom_rect',
#  'geom_ribbon',
#  'geom_step',
#  'geom_text',
#  'geom_tile',
#  'geom_violin',
#  'geom_vline',
#  'geoms',
#  'ggplot',
#  'ggtitle',
#  'labs',
#  'legend',
# ...
