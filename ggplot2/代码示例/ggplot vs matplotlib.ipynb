# %%
from ggplot import *
import matplotlib.pyplot as plt 
print(mpg.head())


#该数据集包含美国环保局提供的燃油经济性数据的子集。它只包含1999年到2008年间每年
#都有新版本的车型 - 这被用作汽车受欢迎程度的替代品。

# manufacturer：制造商
# displ：发动机排量
# cyl:气缸数
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
p=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(size=60,c='black')+geom_point(size=30)
print(p)
# Out:
# <ggplot: (-9223371941071407465)>

# %%
p1 = plt.scatter(mpg.displ, mpg.hwy,c=mpg.cyl)
plt.show()

# %%
import numpy as np
import pandas as pd
from ggplot import *
p=ggplot(pd.DataFrame({'x':np.arange(10)}),aes(x='x')) + stat_function(fun=np.sin,color="red") + stat_function(fun=np.cos,color="blue")
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ceef4aa857b7> in <module>()
#       2 import pandas as pd
#       3 from ggplot import *
# ----> 4 p=ggplot(pd.DataFrame({'x':np.arange(10)}),aes(x='x')) + stat_function(fun=np.sin,color="red") + stat_function(fun=np.cos,color="blue")
#       5 print(p)
#
# NameError: name 'stat_function' is not defined

# %%
import numpy as np
import pandas as pd
from ggplot import *
x = np.random.randn(100)
to_the_power_of = lambda n, p: n ** p
y = x ** 3
y += np.random.randn(100) # add noise
data = pd.DataFrame({'x':x,'y':y})
p=ggplot(aes(x='x',y='y'),data=data) + \
    geom_point() + \
    stat_function(fun=to_the_power_of,args=[3])
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0ffdfed44f88> in <module>()
#       7 y += np.random.randn(100) # add noise
#       8 data = pd.DataFrame({'x':x,'y':y})
# ----> 9 p=ggplot(aes(x='x',y='y'),data=data) +     geom_point() +     stat_function(fun=to_the_power_of,args=[3])
#      10 print(p)
#
# NameError: name 'stat_function' is not defined

# %%
from ggplot import *

p=ggplot(aes(x='date', y='beef'),data=meat)+geom_line()
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5d659a4bdb2b> in <module>()
#       1 from ggplot import *
#       2
# ----> 3 p=ggplot(aes(x='date', y='beef'),data=meat)+geom_line()+geom_smooth(method="lm",se=FALSE)
#       4 print(p)
#
# NameError: name 'geom_smooth' is not defined

# %%
p=ggplot(mtcars, aes(y = 'wt', x = 'mpg', group = 'factor(cyl)'))+\
stat_smooth(method = lm, aes(color = 'factor(cyl)', fill = 'factor(cyl)')) + geom_point(aes(color = 'factor(cyl)'))
print(p)
# Out:
#   File "<ipython-input-14-81a9f7d0251d>", line 1
#     p=ggplot(mtcars, aes(y = 'wt', x = 'mpg', group = 'factor(cyl)'))+stat_smooth(method = lm, aes(color = 'factor(cyl)', fill = 'factor(cyl)')) + geom_point(aes(color = 'factor(cyl)'))
#                                                                                               ^
# SyntaxError: positional argument follows keyword argument

# %%
p=ggplot(mtcars, aes(x = 'mpg',y = 'wt'))+stat_smooth()+geom_point()
print(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-672d11bdea2b> in <module>()
#       1 p=ggplot(mtcars, aes(x = 'mpg',y = 'wt'))+stat_smooth()+geom_point()
# ----> 2 print(p)
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in __repr__(self)
#     114
#     115     def __repr__(self):
# --> 116         self.make()
#     117         # this is nice for dev but not the best for "real"
#     118         if os.environ.get("GGPLOT_DEV"):
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in make(self)
#     634                         if kwargs==False:
#     635                             continue
# --> 636                         layer.plot(ax, facetgroup, self._aes, **kwargs)
#     637
#     638             self.apply_limits()
#
# ...

# %%
p=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(size=60,c='black')+geom_point(size=30)+xlim(2,4)+xlab("enhen")
print(p)
# Out:
# <ggplot: (-9223371877720495016)>

# %%
p=ggplot(aes(x='displ',y='hwy',color='factor(cyl)'),data=mpg)+geom_point(size=60,c='black')+geom_point(size=30)
print(p)
# Out:
# <ggplot: (-9223371877719951928)>
