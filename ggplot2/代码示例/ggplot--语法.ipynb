# %%
p=ggplot(aes(x='carat'),data=diamonds)+geom_histogram(fill='steelblue',alpha=0.5)+coord_polar() #极坐标系--风玫瑰图
print(p)
# Out:
# <ggplot: (129771533772)>

# %%
p=ggplot(mtcars, aes('mpg', 'wt', colour = 'cyl')) +geom_point()+facet_grid('gear')+ggtitle('mtcars')
print(p)
# Out:
# <ggplot: (129771551545)>

# %%
from ggplot import *
print(mtcars.head())

print(mtcars.describe())

# mtcars 数据集为数据框，记录了32种不同品牌的轿车的的11个属性
# name:车型号
# mpg： 数值型，车辆油耗，单位是每加仑英里数
# cyl： 数值型，气缸数
# disp： 数值型，发动机排量
# hp： 数值型，马力数
# drat： 数值型，后桥速比
# wt： 数值型，车身重量，单位为千磅
# qsec： 数值型，四分之一英里加速时间
# vs： 数值型，V/S
# am： 数值型，0=自动挡,1=手动挡
# gear： 数值型，前进档位数
# carb : 数值型，化油器数量
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# ...

# %%
p=ggplot(mtcars, aes(x='mpg',y= 'wt',color='cyl')) + geom_point()+ggtitle('mtcats')
print(p)
# Out:
# <ggplot: (129771111372)>

# %%
import pandas as pd

meat_lng = pd.melt(meat, id_vars=['date']).sample(frac=0.03)

p = ggplot(aes(x='date', y='value'), data=meat_lng) + geom_point() + facet_wrap("variable")
print(p)
# Out:
# <ggplot: (129775373120)>

# %%
p = ggplot(diamonds, aes(x='price')) + geom_density() + facet_grid( "clarity")
print(p)
# Out:
# <ggplot: (-9223371907079936915)>

# %%
p=ggplot(mtcars, aes(x = 'mpg', y = 'wt',color = 'gear'))+geom_point()

print(p)
# Out:
# <ggplot: (129772822883)>

# %%
p=ggplot(mtcars, aes(x = 'mpg', y = 'wt',color = 'gear'))+geom_point(aes(y = 'carb'))
#修改y的映射
print(p)
# Out:
# <ggplot: (129772703352)>

# %%
p=ggplot(mtcars, aes(x = 'mpg', y = 'wt'))+geom_vline(x=[20],linetype='dashed')+geom_point(aes(color = 'gear'))

print(p)
# Out:
# <ggplot: (-9223371907082552695)>

# %%
p=ggplot(mtcars, aes(x = 'mpg', y = 'wt'))+geom_point(aes(color = 'gear'))+geom_vline(x=[20],linetype='dashed')
print(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     131     try:
# --> 132         rgba = _colors_full_map.cache[c, alpha]
#     133     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\pandas\core\generic.py in __hash__(self)
#     878         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# --> 879                         ' hashed'.format(self.__class__.__name__))
#     880
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
p=ggplot(mtcars, aes(x = 'mpg', y = 'wt',color = 'gear'))+geom_point()
#修改y的映射
print(p)
m=p+geom_point(aes(y = 'carb'))
print(m)
# Out:
# <ggplot: (-9223371907083315270)>
# <ggplot: (-9223371907083315270)>

# %%
p=ggplot(mtcars, aes(x = 'mpg', y = 'wt'))+geom_vline(x=[20],linetype='dashed')+geom_hline(y=[4],linetype='dashed')+\
geom_point(aes(color = 'gear')) + geom_point(size=100,alpha=0.3)+geom_point(size=20,c='black')
print(p)
# Out:
# <ggplot: (129775850749)>

# %%
from ggplot import *
p=ggplot(mtcars, aes(x = 'mpg', y = 'wt',color = 'gear'))+geom_point()
print(p)
# Out:
# <ggplot: (127835051882)>

# %%
d =ggplot(diamonds, aes(x = 'clarity', fill = 'cut' )) + geom_histogram(position = "dodge")
print(d)
# Out:
# <ggplot: (127835487629)>

# %%
p=ggplot(mtcars, aes(x = 'mpg', y = 'wt'))+geom_point()

print(p)
# Out:
# <ggplot: (-9223371909018134980)>

# %%
s=ggplot(aes(x='displ',y='hwy',color='factor(cyl)',shape='factor(displ)'),data=mpg)+geom_point()  #注意分类变量要写成'factor(cyl)'而不是factor('cyl)
print(s)
# Out:
# <ggplot: (127836335736)>

# %%
from ggplot import *
print(mtcars.head())

print(mtcars.describe())

# mtcars 数据集为数据框，记录了32种不同品牌的轿车的的11个属性
# name:车型号
# mpg： 数值型，车辆油耗，单位是每加仑英里数
# cyl： 数值型，气缸数
# disp： 数值型，发动机排量
# hp： 数值型，马力数
# drat： 数值型，后桥速比
# wt： 数值型，车身重量，单位为千磅
# qsec： 数值型，四分之一英里加速时间
# vs： 数值型，V/S
# am： 数值型，0=自动挡,1=手动挡
# gear： 数值型，前进档位数
# carb : 数值型，化油器数量
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# ...

# %%
s=ggplot(aes(x='displ',y='hwy',size='cyl',color='factor(cyl)'),data=mpg)+geom_point(size=101) 
print(s)
# Out:
# <ggplot: (-9223371909019078077)>

# %%
s=ggplot(aes(x='displ',y='hwy',group='factor(cyl)'),data=mpg)+geom_point() 
print(s)
# Out:
# <ggplot: (-9223371909018134875)>
