# %%
from ggplot import *
p=ggplot(mpg,aes(x='hwy'))+geom_histogram()
print(p)
# Out:
# <ggplot: (138861686739)>

# %%
p=ggplot(mpg,aes(x='hwy',fill='factor(year)'))+geom_histogram(alpha=0.3,colour='black')
print(p)
# Out:
# <ggplot: (-9223371897992143037)>

# %%
p=ggplot(aes(x='factor(cyl)'), data=mtcars) + geom_bar()
print(p)
# Out:
# <ggplot: (138862548523)>

# %%
p=ggplot(aes(x='factor(cyl)'), data=mtcars)+geom_bar(fill='blue',alpha=0.2,width=0.4)
print(p)
# Out:
# <ggplot: (-9223371925258405323)>

# %%
p=ggplot(aes(x='factor(cyl)'), data=mtcars)+geom_histogram(fill='blue',alpha=0.2)
print(p)
# Out:
# <ggplot: (-9223371925258863065)>

# %%
p=ggplot(aes(x='factor(cyl)',fill='factor(cyl)'), data=mtcars) + geom_bar()
print(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-754741a1dcf0> in <module>()
#       1 p=ggplot(aes(x='factor(cyl)',fill='factor(cyl)'), data=mtcars) + geom_bar()
# ----> 2 print(p)
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in __repr__(self)
#     114
#     115     def __repr__(self):
# --> 116         self.make()
#     117         # this is nice for dev but not the best for "real"
#     118         if os.environ.get("GGPLOT_DEV"):
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in make(self)
#     631                 for ax, facetgroup in self.get_facet_groups(group):
#     632                     for layer in self.layers:
# --> 633                         kwargs = self._prep_layer_for_plotting(layer, facetgroup)
#     634                         if kwargs==False:
#     635                             continue
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in _prep_layer_for_plotting(self, layer, facetgroup)
#     600                 fillcol_raw = self._aes['fill'][:-5]
#     601                 fillcol = self._aes['fill']
# --> 602                 fill_levels = self.data[[fillcol_raw, fillcol]].sort(fillcol_raw)[fillcol].unique()
#     603             else:
#     604                 fill_levels = None
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
p=ggplot(aes(x='factor(cyl)', fill='factor(vs)'), data=mtcars) + \
     geom_bar()
print(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-f527817b019a> in <module>()
#       1 p=ggplot(aes(x='factor(cyl)', fill='factor(vs)'), data=mtcars) +      geom_bar()
# ----> 2 print(p)
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in __repr__(self)
#     114
#     115     def __repr__(self):
# --> 116         self.make()
#     117         # this is nice for dev but not the best for "real"
#     118         if os.environ.get("GGPLOT_DEV"):
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in make(self)
#     631                 for ax, facetgroup in self.get_facet_groups(group):
#     632                     for layer in self.layers:
# --> 633                         kwargs = self._prep_layer_for_plotting(layer, facetgroup)
#     634                         if kwargs==False:
#     635                             continue
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\ggplot\ggplot.py in _prep_layer_for_plotting(self, layer, facetgroup)
#     600                 fillcol_raw = self._aes['fill'][:-5]
#     601                 fillcol = self._aes['fill']
# --> 602                 fill_levels = self.data[[fillcol_raw, fillcol]].sort(fillcol_raw)[fillcol].unique()
#     603             else:
#     604                 fill_levels = None
#
# D:\data_analysis_app\pycharm\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
p=ggplot(aes(x='factor(cyl)', fill='factor(gear)'), data=mtcars) + \
    geom_histogram()
print(p)
# Out:
# <ggplot: (-9223371897992003738)>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "x": np.random.normal(0, 10, 1000),
    "y": np.random.normal(0, 10, 1000),
    "z": np.random.normal(0, 10, 1000)
})
df = pd.melt(df)
p=ggplot(aes(x='value', fill='variable', color='variable'), data=df) + \
    geom_histogram(alpha=0.6)
print(p)
# Out:
# <ggplot: (138862756679)>

# %%
import pandas as pd
import numpy as np
from ggplot import *
df = pd.DataFrame({
    "x": np.random.normal(0, 10, 1000),
    "y": np.random.normal(0, 10, 1000),
    "z": np.random.normal(0, 10, 1000)
})
df = pd.melt(df)

p=ggplot(aes(x='value', fill='variable'), data=df) + \
    geom_histogram()+facet_grid('variable',)
print(p)
# Out:
# <ggplot: (-9223371925259250926)>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "x": np.random.normal(0, 10, 1000),
    "y": np.random.normal(0, 10, 1000),
    "z": np.random.normal(0, 10, 1000)
})
df = pd.melt(df)

p=ggplot(aes(x='value', color='variable'), data=df) + \
    geom_density()
print(p)
q=ggplot(aes(x='value', color='variable', fill='variable'), data=df) + \
    geom_density(alpha=0.6)
print(q)
# Out:
# <ggplot: (-9223371925258760346)>
# <ggplot: (-9223371925258543970)>

# %%
ggplot(aes(x='value', color='variable',fill='factor(variable)'), data=df) + \
    geom_density(alpha=0.6)
# Out:
# <ggplot: (-9223371925258796102)>

# %%
p=ggplot(mpg,aes(x='displ',y='hwy'))+geom_line(color='grey',size=2) 
print(p)
# Out:
# <ggplot: (111596135467)>

# %%
p=ggplot(mpg,aes(x='factor(displ)',y='hwy'))+geom_bar(stat='identity',width=0.8,fill='grey')
##stat='identity'是指不进行统计变换即hwy就是纵
#坐标值因为displ出现众多的重复值，所以分组更多，纵坐标值不断累加
#width为组距，fill为填充色
print(p)
# Out:
# <ggplot: (-9223371925258027758)>

# %%
p=ggplot(mpg,aes(x='displ'))+geom_bar(stat='density')
#一维密度，统计数量
print(p)
# Out:
# <ggplot: (-9223371925258361400)>

# %%
p=ggplot(mpg,aes(x='displ'))+geom_density()
#一维密度，统计数量
print(p)
# Out:
# <ggplot: (-9223371925258260806)>

# %%
p=ggplot(mpg,aes(x='displ',fill='fl'))+geom_histogram(binwidth=0.4,position='dodge')
#位置调整有问题
print(p)
# Out:
# <ggplot: (111596550022)>

# %%
p=ggplot(mpg,aes(x='displ'))+geom_histogram(fill='grey',binwidth=0.18,alpha=0.3)+geom_density(color='red',size=0.8)
print(p)
# Out:
# <ggplot: (-9223371925257778281)>

# %%
p=ggplot(mpg,aes(x='displ',color='factor(fl)'))+geom_density(size=0.5)+ylim(0,1)
print(p)
# Out:
# <ggplot: (-9223371925259633022)>

# %%
small=diamonds.sample(n=1000)
p=ggplot(aes(x='cut'),data=small)+geom_bar()+coord_flip()
print(p)
# Out:
# <ggplot: (111595428051)>

# %%
p=ggplot(aes(x='cyl'), data=mtcars)+geom_histogram(fill='blue',alpha=0.2)
print(p)
# Out:
# <ggplot: (-9223371925257784772)>

# %%
p=ggplot(aes(x='cyl'), data=mtcars)+geom_bar(fill='blue',alpha=0.2)
print(p)
# Out:
# <ggplot: (-9223371925258233228)>

# %%
p=ggplot(aes(x='pageviews'), data=pageviews) + \
    geom_histogram()
print(p)
# Out:
# <ggplot: (111595549746)>

# %%
p=ggplot(aes(x='pageviews'), data=pageviews) + \
    geom_bar()
print(p)
# Out:
# <ggplot: (111596124883)>
