# %%
from ggplot import *
print(mpg.head())
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
from ggplot import *
p=ggplot(mpg,aes(x='hwy'))+geom_histogram()
print(p)
# Out:
# <ggplot: (113048053224)>

# %%
from ggplot import *
p=ggplot(mpg,aes(x='hwy'))+geom_bar()
print(p)
# Out:
# <ggplot: (113048473110)>

# %%
p=ggplot(aes(x='pageviews'), data=pageviews) + \
    geom_histogram()
print(p)
# Out:
# <ggplot: (113048683966)>

# %%
p=ggplot(aes(x='pageviews'), data=pageviews) + \
    geom_bar()
print(p)
# Out:
# <ggplot: (-9223371923805890037)>

# %%
import pandas as pd
import numpy as np
from ggplot import *
df = pd.DataFrame({
    "x": np.random.normal(0, 10, 1000),
    "y": np.random.normal(0, 10, 1000),
    "z": np.random.normal(0, 10, 1000)
})
df = pd.melt(df)

p=ggplot(aes(x='value', fill='variable'), data=df) + \
    geom_histogram()+facet_grid('variable')
print(p)
# Out:
# <ggplot: (-9223371923805860671)>

# %%
import pandas as pd
import numpy as np
from ggplot import *
df = pd.DataFrame({
    "x": np.random.normal(0, 10, 1000),
    "y": np.random.normal(0, 10, 1000),
    "z": np.random.normal(0, 10, 1000)
})
df = pd.melt(df)

p=ggplot(aes(x='value', fill='variable'), data=df) + \
    geom_histogram(alpha=0.1)
print(p)
#目前不支持位置调整（堆积柱状图、堆积百分比柱状图暂时不行）
# Out:
# <ggplot: (-9223371930453676670)>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "x": np.random.normal(0, 10, 1000),
    "y": np.random.normal(0, 10, 1000),
    "z": np.random.normal(0, 10, 1000)
})
df = pd.melt(df)

p=ggplot(aes(x='value', color='variable'), data=df) + \
    geom_density()
print(p)
# Out:
# <ggplot: (113048748790)>

# %%
p=ggplot(mpg,aes(x='factor(fl)',y='hwy'))+geom_boxplot()
print(p)
# Out:
# <ggplot: (-9223371930456757851)>

# %%
p=ggplot(aes(x='carat'),data=diamonds)+geom_bar(fill='steelblue',alpha=0.5)+coord_polar()
print(p)
# Out:
# <ggplot: (-9223371930456720233)>

# %%
p=ggplot(aes(x='carat'),data=diamonds)+geom_histogram(fill='steelblue',alpha=0.5)+coord_polar()
print(p)
# Out:
# <ggplot: (-9223371930457734810)>

# %%
from ggplot import *
p=ggplot(aes(x='carat'),data=diamonds)+geom_histogram(fill='steelblue',alpha=0.3)
print(p)
# Out:
# <ggplot: (106398280445)>

# %%
p=ggplot(diamonds,aes('carat'))+geom_histogram(binwidth=0.1)
print(p)
# Out:
# <ggplot: (106398269430)>

# %%
p=ggplot(aes(x='carat'),data=diamonds)+geom_density()
print(p)
# Out:
# <ggplot: (-9223371930457041250)>

# %%
p=ggplot(mpg,aes(x='factor(fl)',y='hwy',color='factor(fl)'))+geom_boxplot()
print(p)
# Out:
# <ggplot: (106401594530)>
