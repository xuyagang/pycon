# %% [markdown]
# NumPy 包含大量的各种数学运算的函数，包括三角函数，算术运算的函数，复数处理函数等

# %% [markdown]
# NumPy 提供了标准的三角函数：sin()、cos()、tan()

# %%
import numpy as np

# %%
a = np.array([0,30,45,60,90])
# 度数和弧度的转换     angle * np.pi/180
print(np.sin(a*np.pi/180))
# Out:
# [0.         0.5        0.70710678 0.8660254  1.        ]

# %%
print ('计算角度的反正弦，返回值以弧度为单位：')
inv = np.arcsin(np.sin(a*np.pi/180))
print(inv)
# Out:
# 计算角度的反正弦，返回值以弧度为单位：
# [0.         0.52359878 0.78539816 1.04719755 1.57079633]

# %% [markdown]
# ![%E6%AD%A3%E4%BD%99%E5%BC%A6.jpg](attachment:%E6%AD%A3%E4%BD%99%E5%BC%A6.jpg)

# %%
print('通过转化为角度制来检查结果：')
print(np.degrees(inv))
# Out:
# 通过转化为角度制来检查结果：
# [ 0. 30. 45. 60. 90.]

# %%
print('arctan 和 arccos 函数行为类似：')
cos = np.cos(a*np.pi/180)
print(cos)
# Out:
# arctan 和 arccos 函数行为类似：
# [1.00000000e+00 8.66025404e-01 7.07106781e-01 5.00000000e-01
#  6.12323400e-17]

# %% [markdown]
# ### 舍入函数
# - np.around(a,decimals)
#     - a: 数组
#     - decimals: 舍入的小数位数,默认值为0。 如果为负，整数将四舍五入到小数点左侧的位置

# %%
a = np.array([1.0,5.55,  123,  0.567,  25.532])
print('原数组:\n',a)
b = np.around(a)
c = np.around(a,1)
d = np.around(a,-1)
print('舍入后：\n',b)
print(c)
print(d)
# Out:
# 原数组:
#  [  1.      5.55  123.      0.567  25.532]
# 舍入后：
#  [  1.   6. 123.   1.  26.]
# [  1.    5.6 123.    0.6  25.5]
# [  0.  10. 120.   0.  30.]

# %% [markdown]
# - np.floor()

# %%
a = np.array([-1.7,  1.5,  -0.2,  0.6,  10])
print(np.floor(a))
# Out:
# [-2.  1. -1.  0. 10.]

# %% [markdown]
# - np.ceil()

# %%
print(np.ceil(a))
# Out:
# [-1.  2. -0.  1. 10.]
